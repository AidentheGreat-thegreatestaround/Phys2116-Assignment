# %%
powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/0.11.2/install.ps1 | iex"
# Out:
#   Cell In[10], line 1
#     powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/0.11.2/install.ps1 | iex"
#                                 ^
# SyntaxError: invalid syntax

# %%
pip install matplotlib scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# ok now it my turn to try plotting a graph from the NASA DATABASE
# I Seached the database for exoplanets witht the similar mass to jupitor (0.9 to 1.1 times the mass) and are close to their respective sun < 0.1 AU radius


#this stuff is just old data that i probably wont use but am storing anyway just incase.
CoRoT-1 b
CoRoT-12 b
CoRoT-19 b
CoRoT-35 b
HAT-P-13 b
HAT-P-35 b
HAT-P-42 b
HAT-P-5 b
HAT-P-6 b
HAT-P-61 b
HATS-14 b
HATS-3 b
HATS-32 b
HATS-34 b
HATS-55 b
HATS-58 A b
HATS-63 b
HATS-64 b
HD 102956 b
HD 130322 b
HD 179949 b
HD 185269 b
HD 189733 b
HD 202772 A b
HD 285507 b
HD 88133 b
HIP 91258 b
K2-140 b
KELT-12 b
KELT-15 b
KELT-23 A b
KELT-4 A b
KPS-1 b
Kepler-412 b
Kepler-424 b
Kepler-44 b
NGTS-8 b
OGLE-TR-113 b
OGLE-TR-132 b
OGLE-TR-182 b
OGLE-TR-211 b
OGLE-TR-56 b
Qatar-1 b
TOI-1130 c
TOI-1601 b
TOI-1811 b
TOI-2154 b
TOI-2169 A b
TOI-2193 A b
TOI-2202 b
TOI-2420 b
TOI-251 b
TOI-2803 A b
TOI-3135 b
TOI-3688 A b
TOI-3693 b
TOI-3807 b
TOI-4377 b
TOI-4794 b
TOI-5181 A b
TOI-5205 b
TOI-6130 b
TOI-6383 A b
TOI-858 B b
TOI-892 b
TrES-4 b
WASP-1 b
WASP-129 b
WASP-149 b
WASP-16 b
WASP-171 b
WASP-175 b
WASP-180 A b
WASP-185 b
WASP-19 b
WASP-190 b
WASP-2 b
WASP-24 b
WASP-26 b
WASP-28 b
WASP-41 b
WASP-45 b
WASP-48 b
WASP-68 b
WASP-7 b
WASP-74 b
WASP-75 b
WASP-76 b
WASP-79 b
WASP-98 b
XO-1 b
XO-5 b

 [ 0.0225, 0.048,0.0535,0.0488,0.04317,0.04383,0.0431,0.04465,0.04469,0.0332,0.0422,0.04613,0.03304,0.0493,0.03138,0.04013,0.03138,0.0443,0.04016,0.05084,0.03957,0.04928,0.05091,0.04024,0.08,0.0513,0.05092,0.0402,0.033,0.049,0.05412,0.03762,0.04944,0.05105,0.0314,0.02961,0.0684,0.04464,0.068,0.035,0.03144,0.03302,0.02959,0.077,0.03319,0.04,0.03166,0.02897,0.04022,0.03705,0.03958,0.045,0.06708,0.092,0.06206,0.037,0.0579,0.06219,0.04026,0.06562,0.081,0.0807,0.0618,0.0619,0.0617,0.03963,0.04439,0.0492,0.04389,0.07098,0.03185,0.041,0.09564,0.06,0.0456,0.0392,0.0904,0.03444,0.0624,0.0446,0.0344,0.06864,0.04403,0.024,0.0446,0.05741,0.0628,0.0663,0.0405,0.04054,0.04054,0.077,0.0306,0.051,0.05208,0.0591,0.04073,0.088,0.04691,0.0455,0.0813,0.04,0.03966,0.07191,0.03985,0.02536,0.05798,0.077,0.044,0.0457,0.051,0.04756,0.03449,0.0896,0.03997,0.0896,0.0421,0.0522,0.02292,0.0575,0.04872,0.04874,0.036,0.0498,0.04978,0.05235,0.0301,0.0731,0.05237,0.0488,0.04079,0.04075,0.04071,0.05205,0.03607,0.05244,0.057,0.03815,0.01634,0.0259,0.05205,0.0375,0.03815,0.0485]
 [ 1.3,1.24,2.09,1.3,1.699,1.487,1.487,1.213,1.396,1.008,1.443,1.845,1.206,1.117,1.44,1.071,1.44,1.706,1.514,1.206,1.799,1.249,1.453,1.751,1.2,1.83,1.21,1.251,1.144,1.206,1.783,1.071,1.325,1.34,1.25,1.21,1.09,1.081,1.323,1.325,1.77,1.18,1.43,1.341,1.2,1.56,1.514,1.78,1.07,1.24,1.56,1.348,1.24,1.207,1.679,0.915,1.363,1.33,0.946,1.281,0.994,1.5,1.616,1.178,1.01,1.167,1.493,1.25,1.67,1.374,1.09,1.67,1.239,1.208,1.36,1.09,0.24444643,0.93,1.15,0.992,1.16,1.16,1.15,1.13,1.545,1.095,1.254,1.24,1.124,1.32,1.216,1.18833285,1.281,1.551,1.095,0.89,1.2,1.36,1.218,1.67,1.116,1.32,1.65,1.191,1.008,1.28,1.109,1.28,1.332,1.332,1.33,0.899,1.15978431,1.33,1.109,1.252,1.26,1.254,1.47,1.3,1.395,1.039,1.392,1.42,1.47,1.27,1.039,1.381,1.381,1.3,1.27,0.89,1.09,1.03,1.363,0.98,1.089,1.19,1.03,1.164,1.68,1.381,1.1,1.255]
# Out:
#   Cell In[5], line 3
#     CoRoT-1 b
#             ^
# SyntaxError: invalid syntax

# %%
# next i will have to find these planets in the database again and get their mass, distance from the sun and i will filter them to only include the ones that are close to their respective sun < 1 AU
# once i do that i will find their radius, metalicity and other factors that may be important to the graphing of these planets and then i will graph them and see if there are any trends that i can find in the data

# %%
import matplotlib.pyplot as plt
from scipy import stats

#assuming all the planets are the same mass as jupitor so for this graph it will be distance from sun vs radius
x1 = [0.07191,0.07098,0.0731,0.0199,0.02292,0.0813,0.068,0.04389,0.0628,0.0591,0.03963,0.0904,0.0405,0.03762,0.04928,0.031,0.0494,0.04944,0.041,0.04,0.03815,0.04756,0.03138,0.03138,0.03144,0.035,0.0896,0.05412,0.0618,0.092,0.04026,0.0575,0.04024,0.04016,0.03166,0.0269,0.04469,0.0617,0.06206,0.0663,0.0619,0.0301,0.04079,0.04435,0.0624,0.0456,0.04071,0.048,0.0446,0.05205,0.03302,0.0457,0.04403,0.0684,0.0513,0.0498,0.0522,0.0455,0.06864,0.0512,0.04613,0.0504,0.0421,0.0485,0.03966,0.04,0.0492,0.05237,0.05244,0.0375,0.05798,0.04383,0.0431,0.0429,0.036,0.03319,0.05084,0.05092,0.06562,0.06708,0.03957,0.04317,0.0392,0.0259,0.02897,0.024,0.03185,0.0535,0.037,0.02536,0.0332,0.0344,0.05208,0.033,0.03304,0.01634]
 # distance from sun in AU
y1 = [1.18833285,1.5,1.15978431,1.03,1.008,1.124,1.21,0.994,0.93,1.095,0.946,1.25,0.992,1.144,1.206,1.1,1.089,1.206,1.178,1.18,1.039,1.218,1.117,1.071,1.081,1.09,1.116,1.251,0.915,1.07,1.207,1.28,1.249,1.44,1.43,1.03,1.213,1.33,1.24,1.15,1.363,0.899,1.252,1.255,1.374,1.167,1.254,1.24,1.09,1.47,1.323,1.2,1.208,1.34,1.453,1.332,1.191,1.24,1.239,1.19,1.443,0.98,1.65,1.381,1.216,1.32,1.281,1.33,1.395,1.27,1.095,1.487,1.487,1.68,1.28,1.77,1.706,1.751,1.679,1.78,1.514,1.699,1.493,1.42,1.341,1.36,1.616,2.09,1.56,1.551,1.396,1.67,1.545,1.83,1.845,1.392]
 # radius in Jupiter radii
plt.scatter(x1, y1)
plt.xlabel('Distance from Sun (AU)')
plt.ylabel('Radius (Jupiter Radii)')
plt.title('Hot Jupiter Distance from Sun vs Radius')

slope, intercept, r_value, p_value, std_err = stats.linregress(x1, y1)

plt.plot(x1, [slope * xi + intercept for xi in x1], color='red')

# %%
# after plotting this graph i will then try to plot a graph of distance from sun vs other things like metallicity, flux, etc. and see if there are any trends that i can find in the data

# lets try equilibrium temperature vs radius
x2 = [497.7,637,650,737,745,801,962,1100,1114,1153,1160,1170,1171,1196,1200,1203,1210,1242,1244,1276,1292,1300,1304,1311,1345,1364,1367,1379,1397,1398.3,1428,1437,1442,1445,1459,1468,1487,1490,1500,1502,1505,1517,1529,1530,1534,1539,1540,1544,1550,1561,1568,1571,1571.6,1580,1581,1585,1603,1619,1630,1642,1642,1646,1648,1650,1660,1673,1675,1704,1710,1721,1725,1740,1747,1750,1763,1778,1785,1793,1800,1811,1823,1830,1834,1850,1855,1893,1900,1910,1915,1956,2035,2132,2160,2231,2520]
# equalibrium temprature in K
y2 = [1.18833285,1.5,1.15978431,1.03,1.008,1.124,1.21,0.994,0.93,1.095,0.946,1.25,0.992,1.144,1.206,1.1,1.089,1.206,1.178,1.18,1.039,1.218,1.117,1.071,1.081,1.09,1.116,1.251,0.915,1.07,1.207,1.28,1.249,1.44,1.43,1.03,1.213,1.33,1.24,1.15,1.363,0.899,1.252,1.255,1.374,1.167,1.254,1.24,1.09,1.47,1.323,1.2,1.208,1.34,1.453,1.332,1.191,1.24,1.239,1.19,1.443,0.98,1.65,1.381,1.216,1.32,1.281,1.33,1.395,1.27,1.095,1.487,1.487,1.68,1.28,1.77,1.706,1.751,1.679,1.78,1.514,1.699,1.493,1.42,1.341,1.36,1.616,2.09,1.56,1.551,1.396,1.67,1.545,1.83,1.845,1.392]
# radius in Jupiter radii

# Ensure x2 and y2 have the same length to avoid ValueError
if len(x2) != len(y2):
	min_len = min(len(x2), len(y2))
	x2 = x2[:min_len]
	y2 = y2[:min_len]

plt.scatter(x2, y2)
plt.xlabel('Equilibrium Temperature (K)')
plt.ylabel('Radius (Jupiter Radii)')
plt.title('Hot Jupiter Equilibrium Temperature vs Radius')

slope, intercept, r_value, p_value, std_err = stats.linregress(x2, y2)

plt.plot(x2, [slope * xi + intercept for xi in x2], color='red')
